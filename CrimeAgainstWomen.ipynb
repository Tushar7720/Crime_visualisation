# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2360 sha256=9d312e1d1ad3e07be2ec07e806fa9c1a9bb20581191ced47b35d040cfaaf9340
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\44\08\18\d0b86f591e929e063b3134b126c8a77b3758e527fe1a3f6fb8
# Successfully built sklearn
# ...

# %%
df = pd.read_csv("C:\\Users\\dell\\Desktop\\Indian-Crime-Prediction-and-Visualization-Online-Platform-master\\static\\CAW.csv")

df = df.dropna()
df
# Out:
#     Year     Rape  Kidnapping and Abduction of Women & Girls  Dowry Deaths  \
# 0   2001  16075.0                                    14645.0        6851.0
# 1   2002  16373.0                                    14506.0        6822.0
# 2   2003  15847.0                                    13296.0        6208.0
# 3   2004  18233.0                                    15578.0        7026.0
# 4   2005  18359.0                                    15750.0        6787.0
# 5   2006  19348.0                                    17414.0        7618.0
# 6   2007  20737.0                                    20416.0        8093.0
# 7   2008  21467.0                                    22939.0        8172.0
# 8   2009  21397.0                                    25741.0        8383.0
# 9   2010  22172.0                                    29795.0        8391.0
# 10  2011  24206.0                                    35565.0        8618.0
# ...

# %%
from sklearn.metrics import classification_report
print(df.columns)
X1 = df.drop("Total Crimes against Women", axis = 1)
X = X1.values
print(X)
print("\n")
y1 = df["Total Crimes against Women"]
y = y1.values
print(y)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

regressor = LinearRegression()
regressor.fit(X_train,y_train)

print ("Your Test Set is:- \n",X_test)
y_prediction = regressor.predict(X_test)
print("\n")
print(y_test)
print("\n")
print(y_prediction)

#accuracy = regressor.score(X_train,y_train)
#print(classification_report(y_test, y_prediction))
from sklearn.metrics import mean_squared_error

print("the error is :",mean_squared_error(y_test,y_prediction, squared = False))


#print ("\nYour Prediction has the accuracy of-",accuracy,"%")
# Out:
# Index(['Year', 'Rape', 'Kidnapping and Abduction of Women & Girls',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to the modesty of Women', 'Cruelty by Husband or his relatives',
#        'Importation of Girls from Foreign Country', 'Immoral Traffic (P) Act',
#        'Dowry Prohibition Act', 'Indecent Representation of Women (P) Act',
#        'Commission of Sati (P) Act', 'Total Crimes against Women'],
#       dtype='object')
# [[2.00100e+03 1.60750e+04 1.46450e+04 6.85100e+03 3.41240e+04 9.74600e+03
#   4.91700e+04 1.14000e+02 8.79600e+03 3.22200e+03 1.05200e+03 0.00000e+00]
#  [2.00200e+03 1.63730e+04 1.45060e+04 6.82200e+03 3.39430e+04 1.01550e+04
#   4.92370e+04 7.60000e+01 6.59800e+03 2.81600e+03 2.50800e+03 0.00000e+00]
#  [2.00300e+03 1.58470e+04 1.32960e+04 6.20800e+03 3.29390e+04 1.23250e+04
#   5.07030e+04 4.60000e+01 5.51000e+03 2.68400e+03 1.04300e+03 0.00000e+00]
# ...

# %%
rapeX = df.iloc[:,0].values
rapeY = df.iloc[:,1].values

#rapeX_train,rapeX_test,rapeY_train,rapeY_test = cross_validation.train_test_split(rapeX,rapeY,test_size=0.1)
rapeX_test = np.array([2024,2025,2026,2027,2028,2029])

print ("Your Test Set is:- \n",rapeX_test)

clf=LinearRegression()    #clf is the regression classifier
clf.fit(rapeX.reshape(-1, 1),rapeY)   #reshape to convert it from 1 dimentional array to 2D array.
#accuracy = clf.score(rapeX_test.reshape(-1, 1),rapeY_test)
#print accuracy
rapePredict = clf.predict(rapeX_test.reshape(-1,1))
print ("\nPredicted Total Crime for following years is:-\n",rapePredict)
# Out:
# Your Test Set is:-
#  [2024 2025 2026 2027 2028 2029]
#
# Predicted Total Crime for following years is:-
#  [47294.32058824 48800.49852941 50306.67647059 51812.85441177
#  53319.03235294 54825.21029412]
